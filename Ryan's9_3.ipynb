# %% [markdown]
# Just created a dataframe of neighborhoods with three columns: PostalCode, Borough, and Neighborhood

# %%
import pandas as pd
wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wikipedia_page = requests.get(wiki)
df = pd.read_html(wikipedia_page.content, header=0)[0]
df1 = df_raw[df.Borough != 'Not assigned']
df1.head(10)
# Out:
#    Postal Code           Borough                                 Neighborhood
# 2          M3A        North York                                    Parkwoods
# 3          M4A        North York                             Victoria Village
# 4          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5          M6A        North York             Lawrence Manor, Lawrence Heights
# 6          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 8          M9A         Etobicoke                             Islington Avenue
# 9          M1B       Scarborough                               Malvern, Rouge
# 11         M3B        North York                                    Don Mills
# 12         M4B         East York              Parkview Hill, Woodbine Gardens
# 13         M5B  Downtown Toronto                     Garden District, Ryerson

# %% [markdown]
# Notice how I also removed all 'not assigned' in the code above' AND neigbrohoods in one postal code are listed together in one row

# %% [markdown]
# Show number of rows of your dataframe

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# Problem 2 starts now
# We will use a simple piece of code to add in lat/long!

# %%
url2="http://cocl.us/Geospatial_data"
geo_data=pd.read_csv(url2)
geo_data.head(10)

full_table = df.set_index('Postal Code').join(geo_data.set_index('Postal Code'))
full_table = full_table.sample(frac=1).reset_index(drop=True)
full_table.head(20)
# Out:
#              Borough                                       Neighborhood  \
# 0        Scarborough                                             Woburn
# 1        Scarborough                  Guildwood, Morningside, West Hill
# 2         North York                                          Don Mills
# 3          Etobicoke  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 4               York                                Caledonia-Fairbanks
# 5    Central Toronto                The Annex, North Midtown, Yorkville
# 6         North York                                         Willowdale
# 7        Mississauga              Canada Post Gateway Processing Centre
# 8   Downtown Toronto                           Garden District, Ryerson
# 9   Downtown Toronto                           Richmond, Adelaide, King
# 10   Central Toronto                                   Davisville North
# 11         Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# 12        North York                                  Hillcrest Village
# 13  Downtown Toronto                                           Rosedale
# 14        North York                                          Downsview
# 15      West Toronto                       Dufferin, Dovercourt Village
# 16   Central Toronto                           Forest Hill North & West
# 17  Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 18      West Toronto                             Parkdale, Roncesvalles
# 19         Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
#
#      Latitude  Longitude
# 0   43.770992 -79.216917
# 1   43.763573 -79.188711
# 2   43.745906 -79.352188
# 3   43.636258 -79.498509
# 4   43.689026 -79.453512
# 5   43.672710 -79.405678
# 6   43.770120 -79.408493
# 7   43.636966 -79.615819
# 8   43.657162 -79.378937
# 9   43.650571 -79.384568
# 10  43.712751 -79.390197
# 11  43.688905 -79.554724
# 12  43.803762 -79.363452
# 13  43.679563 -79.377529
# 14  43.728496 -79.495697
# 15  43.669005 -79.442259
# 16  43.696948 -79.411307
# 17  43.647177 -79.381576
# 18  43.648960 -79.456325
# 19  43.628841 -79.520999

# %% [markdown]
# Problem 3

# %% [markdown]
# To keep it simple, my dataframe is organized by neighborhood seen above. This gives geographical, neighborhood, and location information
